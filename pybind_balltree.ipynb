# %%
from src import pybind_balltree
import numpy as np 

points = np.random.rand(60000, 128) * 1000

# %%
tree = pybind_balltree.BallTree(points, 6)

# %%
# %%time
tree.kneighbors(points[10], 10)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 37.7 ms
# [[597.5116432712421,
#   68.22032863491711,
#   816.3408005786462,
#   496.5822952325221,
#   325.8949609419842,
#   95.47155643451732,
#   257.26721677135436,
#   263.7354806678832,
#   429.7424889165347,
#   509.8597040308249,
#   258.50286128177777,
#   911.7851810688785,
#   206.0108816883921,
#   973.7770153625464,
#   240.20755215374535,
#   295.3830922824577,
#   33.152284320288274,
#   201.95695009362268,
#   573.3798320609286,
#   573.0203340996128,
#   793.0713398219045,
#   938.9604444149642,
#   740.9012770236684,
#   223.37962661695408,
#   38.84165261373296,
#   890.5632797209739,
#   579.5108853519077,
#   741.5981958265253,
#   424.3564524546675,
#   315.34736092809237,
#   850.584605508856,
#   711.0204958666344,
#   412.10700250236977,
#   645.5831130612802,
#   712.2398015554849,
#   420.19266500890296,
#   532.3114334640671,
#   954.4396129281641,
#   154.3523788086202,
#   702.1286906084525,
#   179.7022270747849,
# ...
